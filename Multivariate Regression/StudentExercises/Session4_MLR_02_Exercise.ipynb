# %% [markdown]
# # Exercise - Multivariate Regression with Red Wine Dataset
#
# The dataset contains score of red wines (between 1-10) based on its composition. The dataset is at https://archive.ics.uci.edu/ml/datasets/Wine+Quality.
# We have to predict the score of wine based on its input.
#
# ### The first step is analysis of the data. Plot & answer the following questions regarding the data.
#
# 1. Determine if there any values missing in any rows/columns. Filter out such rows.
# 2. Find out the correlation of this dataset using pandas. Plot a heatmap of this matrix. Which features have a higher correlation with SCORE? Are there any features who have no correlation with score. Remove such columns.
# 2. Plot different scatter plots of all feature variables with MEDV. Observe trends based on the plots. Are there any wines hving a score of 0, 1, 2, 9, 10? Plot a histogram of the same. (score vs number of wines having that score)
#
#
# ### With the analysis done above of the dataset, remove the columns which are not required. Perform Linear regression on this new filtered dataset.
# 1. The training & test dataset should have data from all wine scores. Each score should have 80% training and 20% testing data.  Perform linear regression on the training dataset. Print the obtained co-efficients for every feature. Which features have more weightage?
# 2. Plot a scatter of test prices vs obtained prices. Obtain the MSE, R^2 score of this model.
#
# ### With the above dataset, perform linear regression with randomly selected training & testing datasets using train_test_split function. Perform the two steps listed above. Which model is better?
#
# ### Perform KFold Cross validation score on both the approaches.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('./data/winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...
