# %% [markdown]
# # Question 1 - Regression Analysis with Automobile Miles Per Gallon Dataset
#
# The auto-mpg dataset is a dataset which gives mileage of a vehicle in mpg(miles per gallon) based on several parameters.
#
# ### Columns are:
# mpg: Miles per gallon (Target variable, i.e to predict)
# cylinders: number of cylinders in vehicle
# displacement: continuous variable  horsepower: power of vehicle
# weight: weight of vehicle
# acceleration: acceleration of vehicle
# model year: year of vehicle model
# origin: origin of model
#
# ## Tasks
# 1. Perform Linear Regression to predict the miles per gallon based on **relevant features**.
#
# ## Mark Distribution
# 1. Data Filtering & Analysis
# 2. Data Visualization with Plotting & Heatmaps with proper labels and axes
# 3. Training of Model with training data
# 4. **Important** The score of the test & entire dataset should be at least 65% to get full marks for the model you create
#
# # Bonus (Proceed if you have enough time!)
# Bonus of 1% will be awarded if you reduce this problem to a single variable linear regression model, with appropriate justification and regression line.

# %%
import pandas as pd
df = pd.read_csv('./data/auto-mpg.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
