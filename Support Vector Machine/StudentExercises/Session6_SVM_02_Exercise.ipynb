# %% [markdown]
# # Exercise - Pima Indians Diabetic Classification with SVM
#
# The Pima Indians Dataset aims to predict whether a person has diabetes or not based on a set of features like Age, Gender, Insulin, etc. The dataset is available at https://www.kaggle.com/uciml/pima-indians-diabetes-database
#
# The dataset has a lot of missing values (which are labeled as 0).
#
# ### Perform the following operations:
# 1. Read the dataset into python using pandas. Plot the histogram of the outcome column. (i.e who have diabetes and not)
# 2. We have to first determine which features are important. Pairwise plot scatters of every feature(example plot attached below). Which features give you a distinction between diabetics and non diabetics?  Choose the best 3.
# 3. Once you choose the best 3, impute the missing values in each of the columns. You can either use the mean of all values or use the most frequent one in the column.
# 3. Initialize a SVM kernel (decide the kernel based on the scatter plots). Split your dataset into training and testing. It should be 80:20 split with random state 44. Apply SVM on the 3 best features and get its classification report & confusion matrix.
# 4. Perform KFold cross validation scoring on the dataset's entire features, and separately on the 3 you chose. What is your observation?
# 5. Plot the SVM for any 2 of the 3 features you chose.
#
# ![Image](./data/diabetes_plot.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("./data/diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1       85             66             29        0  26.6
# 1            1       89             66             23       94  28.1
# 2            5      116             74              0        0  25.6
# 3           10      115              0              0        0  35.3
# 4            4      110             92              0        0  37.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.351   31        0
# 1                     0.167   21        0
# 2                     0.201   30        0
# 3                     0.134   29        0
# 4                     0.191   30        0
